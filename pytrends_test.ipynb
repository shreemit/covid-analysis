# %%
import pandas as pd
import pytrends
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
KEYWORDS=['Covid','Flu','Beach']
KEYWORDS_CODES=[pytrend.suggestions(keyword=i)[0] for i in KEYWORDS] 
df_CODES= pd.DataFrame(KEYWORDS_CODES)

# %%
# print
print(df_CODES)
# Out:
#          mid        title      type
# 0  /m/01cpyy  Coronavirus     Virus
# 1   /m/0cycc    Influenza   Disease
# 2   /m/0b3yr        Beach  Landform

# %%
EXACT_KEYWORDS=list(df_CODES['mid'])
DATE_INTERVAL='today 5-y'
COUNTRY=["US-AL","US-GA"] #Use this link for iso country code
CATEGORY=0 # Use this link to select categories
SEARCH_TYPE='' #default is 'web searches',others include 'images','news','youtube','froogle' (google shopping)

# %%
Individual_EXACT_KEYWORD = list(zip(*[iter(EXACT_KEYWORDS)]*1))
Individual_EXACT_KEYWORD = [list(x) for x in Individual_EXACT_KEYWORD]
dicti = {}
i = 1
for Country in COUNTRY:
    for keyword in Individual_EXACT_KEYWORD:
        pytrend.build_payload(kw_list=keyword,timeframe = DATE_INTERVAL,geo = Country,cat=CATEGORY,gprop=SEARCH_TYPE) 
        dicti[i] = pytrend.interest_over_time()
        i+=1
df_trends = pd.concat(dicti, axis=1)

# %%
df_trends.columns = df_trends.columns.droplevel(0) #drop outside header
df_trends = df_trends.drop('isPartial', axis = 1) #drop "isPartial"
df_trends.reset_index(level=0,inplace=True) #reset_index
df_trends.columns=['date','Covid-AL','FLU-AL','Beach-AL','Covid-GA','FLU-GA','Beach-GA']

# %%
df_trends
# Out:
#           date  Covid-AL  FLU-AL  Beach-AL  Covid-GA  FLU-GA  Beach-GA
# 0   2015-05-31         0       1        52         0       2        52
# 1   2015-06-07         0       2        55         0       2        54
# 2   2015-06-14         0       2        62         0       2        57
# 3   2015-06-21         0       2        62         0       2        60
# 4   2015-06-28         0       2        56         0       2        68
# 5   2015-07-05         0       3        60         0       2        63
# 6   2015-07-12         0       1        51         0       2        58
# 7   2015-07-19         0       1        53         0       1        54
# 8   2015-07-26         0       2        51         0       2        51
# 9   2015-08-02         0       2        39         0       2        43
# 10  2015-08-09         0       2        32         0       2        41
# 11  2015-08-16         0       2        35         0       3        32
# 12  2015-08-23         0       3        32         0       2        32
# 13  2015-08-30         0       4        29         0       4        31
# 14  2015-09-06         0       5        29         0       4        31
# 15  2015-09-13         0       6        21         0       5        27
# 16  2015-09-20         0      10        22         0       7        24
# 17  2015-09-27         0       9        21         0       8        22
# 18  2015-10-04         0      11        23         0       9        22
# 19  2015-10-11         0      10        22         0       8        24
# 20  2015-10-18         0       9        21         0      11        19
# 21  2015-10-25         0      11        20         0       9        19
# 22  2015-11-01         0       8        17         0       7        17
# 23  2015-11-08         0       6        14         0       7        20
# 24  2015-11-15         0       7        17         0       8        18
# 25  2015-11-22         0       6        17         0       5        17
# 26  2015-11-29         0       4        16         0       6        19
# 27  2015-12-06         0       6        16         0       5        18
# 28  2015-12-13         0       6        16         0       5        18
# 29  2015-12-20         0       6        19         0       5        22
# ..         ...       ...     ...       ...       ...     ...       ...
# 231 2019-11-03         0      15        16         0      11        18
# 232 2019-11-10         0      14        12         0      12        16
# 233 2019-11-17         0      18        15         0      12        17
# 234 2019-11-24         0      15        15         0      12        18
# 235 2019-12-01         0      14        14         0      13        17
# 236 2019-12-08         0      19        16         0      18        16
# 237 2019-12-15         0      26        19         0      25        19
# 238 2019-12-22         0      32        21         0      32        22
# 239 2019-12-29         0      25        21         0      26        26
# 240 2020-01-05         0      23        24         0      25        26
# 241 2020-01-12         0      23        27         0      24        28
# 242 2020-01-19         3      28        29         4      23        27
# 243 2020-01-26         8      46        23        11      32        25
# 244 2020-02-02         5      45        27         7      31        26
# 245 2020-02-09         4      35        27         6      23        28
# 246 2020-02-16         3      30        30         4      19        30
# 247 2020-02-23        14      43        28        17      31        28
# 248 2020-03-01        21      45        29        32      42        29
# 249 2020-03-08        67      79        34        76      69        32
# 250 2020-03-15       100      70        71       100      58        45
# 251 2020-03-22        77      51        26        81      47        27
# 252 2020-03-29        64      44        21        66      40        25
# 253 2020-04-05        57      30        26        64      28        29
# 254 2020-04-12        41      22        31        49      19        30
# 255 2020-04-19        31      20        41        39      21        38
# 256 2020-04-26        18      18        57        23      17        45
# 257 2020-05-03        15      14        55        19      13        48
# 258 2020-05-10        13      14        67        17      11        59
# 259 2020-05-17        11      14        76        13      10        70
# 260 2020-05-24        10      17       100        12      11       100
#
# [261 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

import seaborn as sns

sns.set(color_codes=True)
dx = df_trends.plot(figsize = (12,8),x="date", y=['Covid-GA','FLU-GA','Beach-GA'], kind="line", title = "Covid Google Trends")
dx.set_xlabel('Date')
dx.set_ylabel('Trends Index')
dx.tick_params(axis='both', which='both', labelsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-a3f2d36f3266> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 import seaborn as sns
#       4
#       5 sns.set(color_codes=True)
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\seaborn\__init__.py in <module>()
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\seaborn\rcmod.py in <module>()
#       4 import matplotlib as mpl
#       5 import warnings
# ----> 6 from . import palettes, _orig_rc_params
#       7
#       8
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\seaborn\palettes.py in <module>()
#      10 from .external.six.moves import range
#      11
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .colors import xkcd_rgb, crayons
#      14
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\seaborn\utils.py in <module>()
#       5
#       6 import numpy as np
# ----> 7 from scipy import stats
#       8 import pandas as pd
#       9 import matplotlib as mpl
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\__init__.py in <module>()
#     154     # This makes "from scipy import fft" return scipy.fft, not np.fft
#     155     del fft
# --> 156     from . import fft
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\fft\__init__.py in <module>()
#      74 from __future__ import division, print_function, absolute_import
#      75
# ---> 76 from ._basic import (
#      77     fft, ifft, fft2, ifft2, fftn, ifftn,
#      78     rfft, irfft, rfft2, irfft2, rfftn, irfftn,
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\fft\_basic.py in <module>()
# ----> 1 from scipy._lib.uarray import generate_multimethod, Dispatchable
#       2 import numpy as np
#       3
#       4
#       5 def _x_replacer(args, kwargs, dispatchables):
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\_lib\uarray.py in <module>()
#      25     from uarray import _Function
#      26 else:
# ---> 27     from ._uarray import *
#      28     from ._uarray import _Function
#      29
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\_lib\_uarray\__init__.py in <module>()
#     112 """
#     113
# --> 114 from ._backend import *
#     115
#     116 __version__ = '0.5.1+5.ga864a57.scipy'
#
# c:\users\sastry\appdata\local\programs\python\python35\lib\site-packages\scipy\_lib\_uarray\_backend.py in <module>()
# ----> 1 from typing import (
#       2     Callable,
#       3     Iterable,
#       4     Dict,
#       5     Tuple,
#
# ImportError: cannot import name 'Type'

# %%
# Same data downloaded from browser https://trends.google.com/trends/explore?date=today%205-y&geo=US-GA&q=FLU,Beach
